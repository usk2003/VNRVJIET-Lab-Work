# %% [markdown]
# # **ML Lab - Navie Bayes**
# Urlana Suresh Kumar - 22071A6662

# %% [markdown]
# # Naive Bayes Classification for Breast Cancer Diagnosis
#
# This notebook demonstrates how to implement the Naive Bayes algorithm using two approaches: Gaussian (continuous) and Categorical for breast cancer diagnosis.
#
# We start with exploratory data analysis (EDA), then proceed to model building and evaluation.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# # Step 1 : Loading Dataset And Basic EDA

# %%
data = pd.read_csv("/content/Breast_cancer_data.csv")
data.head(5)
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data["diagnosis"].hist()
# Out:
# <Axes: >

# %%
corr = data.iloc[:,:-1].corr(method="pearson")
cmap = sns.diverging_palette(250,354,80,60,center='dark',as_cmap=True)
sns.heatmap(corr, vmax=1, vmin=-.5, cmap=cmap, square=True, linewidths=.2)
# Out:
# <Axes: >

# %%
data = data[["mean_radius", "mean_texture", "mean_smoothness", "diagnosis"]]
data.head(5)
# Out:
#    mean_radius  mean_texture  mean_smoothness  diagnosis
# 0        17.99         10.38          0.11840          0
# 1        20.57         17.77          0.08474          0
# 2        19.69         21.25          0.10960          0
# 3        11.42         20.38          0.14250          0
# 4        20.29         14.34          0.10030          0

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
sns.histplot(data, ax=axes[0], x="mean_radius", kde=True, color='r')
sns.histplot(data, ax=axes[1], x="mean_smoothness", kde=True, color='b')
sns.histplot(data, ax=axes[2], x="mean_texture", kde=True)
# Out:
# <Axes: xlabel='mean_texture', ylabel='Count'>

# %% [markdown]
# # Step 2 : Calculate P(Y=y) for all possible y

# %%
def calculate_prior(df, Y):
    classes = sorted(list(df[Y].unique()))
    prior = []
    for i in classes:
        prior.append(len(df[df[Y]==i])/len(df))
    return prior

# %% [markdown]
# ## Approach 1: Calculate P(X=x|Y=y) using Gaussian dist.

# %%
def calculate_likelihood_gaussian(df, feat_name, feat_val, Y, label):
    feat = list(df.columns)
    df = df[df[Y]==label]
    mean, std = df[feat_name].mean(), df[feat_name].std()
    p_x_given_y = (1 / (np.sqrt(2 * np.pi) * std)) *  np.exp(-((feat_val-mean)**2 / (2 * std**2 )))
    return p_x_given_y

# %% [markdown]
# ### Calculate P(X=x1|Y=y)P(X=x2|Y=y)...P(X=xn|Y=y) * P(Y=y) for all y and find the maximum

# %%
def naive_bayes_gaussian(df, X, Y):
    # get feature names
    features = list(df.columns)[:-1]

    # calculate prior
    prior = calculate_prior(df, Y)

    Y_pred = []
    # loop over every data sample
    for x in X:
        # calculate likelihood
        labels = sorted(list(df[Y].unique()))
        likelihood = [1]*len(labels)
        for j in range(len(labels)):
            for i in range(len(features)):
                likelihood[j] *= calculate_likelihood_gaussian(df, features[i], x[i], Y, labels[j])

        # calculate posterior probability (numerator only)
        post_prob = [1]*len(labels)
        for j in range(len(labels)):
            post_prob[j] = likelihood[j] * prior[j]

        Y_pred.append(np.argmax(post_prob))

    return np.array(Y_pred)

# %% [markdown]
# ### Test Gaussian model

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=.2, random_state=41)

X_test = test.iloc[:,:-1].values
Y_test = test.iloc[:,-1].values
Y_pred = naive_bayes_gaussian(train, X=X_test, Y="diagnosis")

from sklearn.metrics import confusion_matrix, f1_score
print(confusion_matrix(Y_test, Y_pred))
print(f1_score(Y_test, Y_pred))
# Out:
# [[36  4]
#  [ 0 74]]
# 0.9736842105263158

# %% [markdown]
# ### Convert continuous features to Categorical features

# %%
data["cat_mean_radius"] = pd.cut(data["mean_radius"].values, bins = 3, labels = [0,1,2])
data["cat_mean_texture"] = pd.cut(data["mean_texture"].values, bins = 3, labels = [0,1,2])
data["cat_mean_smoothness"] = pd.cut(data["mean_smoothness"].values, bins = 3, labels = [0,1,2])

data = data.drop(columns=["mean_radius", "mean_texture", "mean_smoothness"])
data = data[["cat_mean_radius",	"cat_mean_texture",	"cat_mean_smoothness", "diagnosis"]]
data.head(10)
# Out:
#   cat_mean_radius cat_mean_texture cat_mean_smoothness  diagnosis
# 0               1                0                   1          0
# 1               1                0                   0          0
# 2               1                1                   1          0
# 3               0                1                   2          0
# 4               1                0                   1          0
# 5               0                0                   2          0
# 6               1                1                   1          0
# 7               0                1                   1          0
# 8               0                1                   2          0
# 9               0                1                   1          0

# %% [markdown]
# ## Approach 2: Calculate P(X=x|Y=y) categorically

# %%
def calculate_likelihood_categorical(df, feat_name, feat_val, Y, label):
    feat = list(df.columns)
    df = df[df[Y]==label]
    p_x_given_y = len(df[df[feat_name]==feat_val]) / len(df)
    return p_x_given_y

# %% [markdown]
# ### Calculate P(X=x1|Y=y)P(X=x2|Y=y)...P(X=xn|Y=y) * P(Y=y) for all y and find the maximum

# %%
def naive_bayes_categorical(df, X, Y):
    # get feature names
    features = list(df.columns)[:-1]

    # calculate prior
    prior = calculate_prior(df, Y)

    Y_pred = []
    # loop over every data sample
    for x in X:
        # calculate likelihood
        labels = sorted(list(df[Y].unique()))
        likelihood = [1]*len(labels)
        for j in range(len(labels)):
            for i in range(len(features)):
                likelihood[j] *= calculate_likelihood_categorical(df, features[i], x[i], Y, labels[j])

        # calculate posterior probability (numerator only)
        post_prob = [1]*len(labels)
        for j in range(len(labels)):
            post_prob[j] = likelihood[j] * prior[j]

        Y_pred.append(np.argmax(post_prob))

    return np.array(Y_pred)

# %% [markdown]
# ### Test Categorical model

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=.2, random_state=41)

X_test = test.iloc[:,:-1].values
Y_test = test.iloc[:,-1].values
Y_pred = naive_bayes_categorical(train, X=X_test, Y="diagnosis")

from sklearn.metrics import confusion_matrix, f1_score
print(confusion_matrix(Y_test, Y_pred))
print(f1_score(Y_test, Y_pred))
# Out:
# [[38  2]
#  [ 5 69]]
# 0.9517241379310345

# %% [markdown]
# # Conclusion
#
# In this notebook, we implemented two versions of the Naive Bayes algorithm for breast cancer diagnosis:
# 1. **Gaussian Naive Bayes Model** - used for continuous features.
# 2. **Categorical Naive Bayes Model** - used for discretized (categorical) features.
#
# Both approaches were tested and evaluated based on the F1 score and confusion matrix. The F1 score indicates how well each model balances precision and recall, while the confusion matrix provides insight into each model's performance in classifying positive and negative cases.
#
# Let's compare the two models by calculating and displaying their performance metrics.

# %%
from sklearn.metrics import accuracy_score

# Categorical Model Results
print("\nCategorical Naive Bayes Model:")
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred_cat))
print("F1 Score:", f1_score(Y_test, Y_pred_cat))
print("Accuracy:", accuracy_score(Y_test, Y_pred_cat))

print("\nConclusion: The Categorical Naive Bayes Model performed better.")
# Out:
# Categorical Naive Bayes Model:
# Confusion Matrix:
#  [[38  2]
#  [ 5 69]]
# F1 Score: 0.9517241379310345
# Accuracy: 0.9385964912280702
#
# Conclusion: The Categorical Naive Bayes Model performed better.
